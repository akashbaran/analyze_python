# %%
import datetime
import matplotlib.pyplot as plt
from pandas_datareader import data, wb
from matplotlib import style
from pandas.util.testing import assert_frame_equal   # added because of error, remove and try

style.use('fivethirtyeight')

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2015, 7, 28)

# leveraging existing apis from the web to use as a dataframe, here source is yahoo
att = data.DataReader("T", "yahoo", start, end)

print(att.head())
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2009-12-31  28.430000  28.020000  28.290001  28.030001  16071000.0  15.707478
# 2010-01-04  28.610001  28.280001  28.410000  28.580000  29136600.0  16.015694
# 2010-01-05  28.730000  28.350000  28.700001  28.440001  35234500.0  15.937237
# 2010-01-06  28.030001  27.549999  27.950001  27.610001  37894600.0  15.704037
# 2010-01-07  27.690001  27.120001  27.580000  27.299999  33600300.0  15.527716

# %%
highs = att['High'].tolist()
print(highs)
# Out:
# [28.43000030517578, 28.610000610351562, 28.729999542236328, 28.030000686645508, 27.690000534057617, 27.389999389648438, 27.219999313354492, 27.110000610351562, 27.100000381469727, 26.850000381469727, 26.270000457763672, 26.25, 26.030000686645508, 25.979999542236328, 25.829999923706055, 25.899999618530273, 25.510000228881836, 26.1200008392334, 26.149999618530273, 25.75, 25.709999084472656, 25.84000015258789, 25.809999465942383, 25.489999771118164, 25.309999465942383, 25.270000457763672, 25.420000076293945, 25.25, 25.3799991607666, 25.149999618530273, 25.489999771118164, 25.520000457763672, 25.530000686645508, 25.399999618530273, 25.15999984741211, 25.030000686645508, 24.950000762939453, 24.860000610351562, 24.90999984741211, 25.06999969482422, 25.059999465942383, 25.030000686645508, 25.0, 25.049999237060547, 25.360000610351562, 25.729999542236328, 25.719999313354492, 25.600000381469727, 25.729999542236328, 25.799999237060547, 25.989999771118164, 25.989999771118164, 26.09000015258789, 
# ...

# %%
# above u see output as a list
# now without the toList()
highz = att['High']
print(highz)
# Out:
# Date
# 2009-12-31    28.430000
# 2010-01-04    28.610001
# 2010-01-05    28.730000
# 2010-01-06    28.030001
# 2010-01-07    27.690001
#                 ...
# 2015-07-22    34.349998
# 2015-07-23    34.340000
# 2015-07-24    35.090000
# 2015-07-27    34.660000
# 2015-07-28    34.580002
# Name: High, Length: 1402, dtype: float64

# %%
# while highs is printed as a list, highz is printed as a Series
# indexing can be used like in a list
print(highs[-1])      # last one
# Out:
# 34.58000183105469
